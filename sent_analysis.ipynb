# %%
#Importing required libraries
import pandas as pd
import nltk

# %%
#Reading the dataset
text_sentiment_data = pd.read_csv('tweets.csv')

# %%
text_sentiment_data.head(10)
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
# 5  570300767074181121          negative                        1.0000
# 6  570300616901320704          positive                        0.6745
# 7  570300248553349120           neutral                        0.6340
# 8  570299953286942721          positive                        0.6559
# 9  570295459631263746          positive                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
# 5     Can't Tell                     0.6842  Virgin America
# 6            NaN                     0.0000  Virgin America
# 7            NaN                        NaN  Virgin America
# 8            NaN                        NaN  Virgin America
# 9            NaN                        NaN  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
# 5                    NaN    jnardino                 NaN              0
# 6                    NaN  cjmcginnis                 NaN              0
# 7                    NaN       pilot                 NaN              0
# 8                    NaN    dhepburn                 NaN              0
# 9                    NaN  YupitsTate                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
# 5  @VirginAmerica seriously would pay $30 a fligh...         NaN
# 6  @VirginAmerica yes, nearly every time I fly VX...         NaN
# 7  @VirginAmerica Really missed a prime opportuni...         NaN
# 8    @virginamerica Well, I didn't…but NOW I DO! :-D         NaN
# 9  @VirginAmerica it was amazing, and arrived an ...         NaN
#
#                tweet_created    tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800               NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800               NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800         Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800               NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800               NaN  Pacific Time (US & Canada)
# 5  2015-02-24 11:14:33 -0800               NaN  Pacific Time (US & Canada)
# 6  2015-02-24 11:13:57 -0800  San Francisco CA  Pacific Time (US & Canada)
# 7  2015-02-24 11:12:29 -0800       Los Angeles  Pacific Time (US & Canada)
# 8  2015-02-24 11:11:19 -0800         San Diego  Pacific Time (US & Canada)
# 9  2015-02-24 10:53:27 -0800       Los Angeles  Eastern Time (US & Canada)

# %%
text_sentiment_data.shape
# Out:
# (14640, 15)

# %%
#Filtering out entries with low confidence
text_sentiment_df = text_sentiment_data.drop(text_sentiment_data[text_sentiment_data['airline_sentiment_confidence']<0.5].index, axis= 0)

# %%
text_sentiment_df.shape
# Out:
# (14404, 15)

# %%
X = text_sentiment_df['text']
Y = text_sentiment_df['airline_sentiment']

# %%
# Cleaning our text data:

from nltk.corpus import stopwords
nltk.download('stopwords')
import string
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Initializing stopwords and punctuation so we can remove them from our text data
words_stop = stopwords.words('english')
punctuations = string.punctuation

# %%
#With the help of regular expressions we will consider only the text part and remove all the numbers, special characters from the text data
import re
nltk.download('wordnet')

#First take text data and convert it to lower case and then lemmatize it (reduce it to its lower form, for exapmle: walked -> walk)
cleaned_text_data = []
for i in range(len(X)):
  text = re.sub('[^a-zA-Z]', ' ',X.iloc[i])
  text = text.lower().split()
  text = [lemmatizer.lemmatize(word) for word in text if (word not in words_stop) and (word not in punctuations)]
  text = ' '.join(text)
  cleaned_text_data.append(text)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\aryan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
cleaned_text_data
# Out:
# ['virginamerica dhepburn said',
#  'virginamerica today must mean need take another trip',
#  'virginamerica really aggressive blast obnoxious entertainment guest face amp little recourse',
#  'virginamerica really big bad thing',
#  'virginamerica seriously would pay flight seat playing really bad thing flying va',
#  'virginamerica yes nearly every time fly vx ear worm go away',
#  'virginamerica really missed prime opportunity men without hat parody http co mwpg grezp',
#  'virginamerica well',
#  'virginamerica amazing arrived hour early good',
#  'virginamerica know suicide second leading cause death among teen',
#  'virginamerica lt pretty graphic much better minimal iconography',
#  'virginamerica great deal already thinking nd trip australia amp even gone st trip yet p',
#  'virginamerica virginmedia flying fabulous seductive sky u take stress away travel http co ahlxhhkiyn',
#  'virginamerica thanks',
#  'virginamerica sfo pdx schedule still mia',
#  'virginamerica excited first cross country flight lax mco heard nothing great thing virgin america daystogo',
#  'virginamerica flew nyc sfo last week fully sit seat due two large gentleman either side help',
#  'flying virginamerica',
#  'virginamerica know would amazingly awesome bos fll please want fly',
#  'virginamerica first fare may three time carrier seat available select',
#  'virginamerica love graphic http co ut grrwaaa',
#  'virginamerica love hipster innovation feel good brand',
#  'virginamerica making bos gt la non stop permanently anytime soon',
#  'virginamerica guy messed seating reserved seating friend guy gave seat away want free internet',
#  'virginamerica status match program applied three week called emailed response',
#  'virginamerica happened ur vegan food option least say ur site know able eat anything next hr fail',
#  'virginamerica miss worry together soon',
#  'virginamerica amazing get cold air vent vx noair worstflightever roasted sfotobos',
#  'virginamerica lax ewr middle seat red eye noob maneuver sendambien andchexmix',
#  'virginamerica hi bked cool birthday trip add elevate cause entered middle name flight booking problem',
#  'virginamerica hour operation club sfo posted online current',
#  'virginamerica help left expensive headphone flight iad lax today seat one answering l amp f number lax',
#  'virginamerica awaiting return phone call would prefer use online self service option',
#  'virginamerica great news america could start flight hawaii end year http co r p zy fe via pacificbiznews',
#  'nice rt virginamerica vibe moodlight takeoff touchdown moodlitmonday sciencebehindtheexperience http co unxtqp',
#  'virginamerica moodlighting way fly best experience ever cool calming moodlitmonday',
#  'virginamerica freddieawards done done best airline around hand',
#  'virginamerica book flight hawaii',
#  'virginamerica chat support working site http co vhp gtdwpk',
#  'virginamerica view downtown los angeles hollywood sign beyond rain mountain http co dw nf ibtr',
#  'virginamerica hey first time flyer next week excited hard time getting flight added elevate account help',
#  'virginamerica plz help win bid upgrade flight lax gt sea',
#  'virginamerica unused ticket moved new city fly fly expires travelhelp',
#  'virginamerica flight leaving dallas seattle time feb',
#  'virginamerica elevategold good reason rock',
#  'virginamerica dream http co oa drfaoq http co lwwdac khx',
#  'virginamerica wow blew mind',
#  'virginamerica ladygaga carrieunderwood last night tribute soundofmusic oscar ladygaga think carrieunderwood agree',
#  'virginamerica ladygaga carrieunderwood entertaining',
#  'virginamerica flight way supposed take minute ago website still show time flight thanks',
#  'virginamerica ladygaga carrieunderwood julie andrew way though ladygaga impressive carrieunderwood',
#  'virginamerica wish flew atlanta soon',
#  'virginamerica ladygaga carrieunderwood julie andrew hand',
#  'virginamerica flight leaving dallas la february th',
#  'virginamerica hi excited lga gt dal deal trying book since last week amp page never load thx',
#  'virginamerica know need spotify stat guiltypleasures',
#  'virginamerica ladygaga carrieunderwood lady gaga amazing',
#  'virginamerica ladygaga carrieunderwood carrie',
#  'virginamerica new marketing song http co f lfulcbq let u know think',
#  'virginamerica ladygaga carrieunderwood julie andrew first lady gaga wow last night carrie meh',
#  'virginamerica called week ago adding flight elevate still shown help',
#  'virginamerica ladygaga carrieunderwood great go carrieunderwood',
#  'virginamerica ladygaga carrieunderwood sorry mary martin first',
#  'virginamerica ladygaga carrieunderwood love three really beat classic',
#  'virginamerica flight dal dca pm tried check could status please',
#  'virginamerica heyyyy guyyyys trying get hour someone call please',
#  'virginamerica hi virgin hold minute earlier flight la nyc tonight earlier pm',
#  'virginamerica congrats winning travelzoo award best deal airline u http co kj iljaebv',
#  'virginamerica everything fine lost bag',
#  'virginamerica need change reservation virgin credit card need modify phone waive change fee online',
#  'virginamerica emailed customer service team let know need tracking number',
#  'virginamerica hi booked flight need add baggage',
#  'virginamerica airline awesome lax loft need step game dirty table floor http co hy vrfhjht',
#  'virginamerica worried great ride new plane great crew airline like',
#  'virginamerica awesome flew yall sat morning way correct bill',
#  'virginamerica watch best student film country foot cmfat foot http co kek pdmgif',
#  'virginamerica first time flying different rate policy medium bag thanks',
#  'virginamerica going customer service anyway speak human asap thank',
#  'virginamerica happened doom',
#  'virginamerica supp biz traveler like southwestair customer service like jetblue neverflyvirginforbusiness',
#  'virginamerica applied member inflight crew team im interested flightattendant dreampath g',
#  'virginamerica best whenever begrudgingly use airline delayed late flight',
#  'virginamerica interesting flying cancelled flight next four flight planned neverflyvirginforbusiness',
#  'virginamerica disappointing experience shared every business traveler meet neverflyvirgin',
#  'virginamerica trouble adding flight wife booked elevate account help http co px hqoks r',
#  'virginamerica bring reservation online using flight booking problem code',
#  'virginamerica random q distribution elevate avatar bet kitty disproportionate share http co aptzpurop',
#  'virginamerica lt flying va life happens trying change trip jperhi help va home page let',
#  'virginamerica site back',
#  'virginamerica rnp yeah know',
#  'virginamerica hi get point elevate account recent flight add flight point account',
#  'virginamerica like tv interesting video disappointed cancelled flightled flight flight went jfk saturday',
#  'virginamerica landed lax hour late flight bag check business travel friendly nomorevirgin',
#  'virginamerica flight redirected',
#  'virginamerica website btw new website great user experience time another redesign',
#  'virginamerica check add bag website working tried desktop mobile http co avyqdmpi',
#  'virginamerica let scanned passenger leave plane told someone remove bag st class bin uncomfortable',
#  'virginamerica phone number find call flight reservation',
#  'virginamerica anyone anything today website useless one answering phone',
#  'virginamerica trying add boy prince ressie sf thursday virginamerica lax http co gsb j c gm',
#  'virginamerica must traveler miss flight late flight check bag missed morning appointment lost business sfo lax',
#  'virginamerica check new music http co marcnocwzn',
#  'virginamerica direct flight fll gt sfo unexpected layover vega fuel yet peep next bought vega flight sneaky',
#  'virginamerica late flight bag check lost business missed flight apt three people flight exp',
#  'virginamerica amazing customer service raeann sf best customerservice virginamerica flying',
#  'virginamerica called service line hung awesome sarcasm',
#  'virginamerica site tripping trying check getting plain text version reluctant enter card info',
#  'virginamerica scheduled sfo dal flight today changed th due weather look like flight still',
#  'virginamerica getaway deal may one way lot cool city http co tzzjhuibch cheapflights farecompare',
#  'virginamerica getaway deal may one way lot cool city http co rpdbpx wnd cheapflights farecompare',
#  'virginamerica getaway deal may one way lot cool city http co b xi yg cheapflights farecompare',
#  'virginamerica getaway deal may one way lot cool city http co qdljhsloi cheapflights farecompare',
#  'virginamerica great week',
#  'virginamerica concerned fly plane need delayed due tech stop',
#  'virginamerica best airline flown easy change reservation helpful representative amp comfortable flying experience',
#  'virginamerica another rep kicked butt naelah represents team beautifully thank',
#  'virginamerica beautiful front end design right cool still book ticket b c back end secure',
#  'virginamerica love team running gate e la tonight waited delayed flight kept thing entertaining',
#  'virginamerica use another browser amp brand reputation built tech response cross browser compatible website',
#  'virginamerica flight flight booking problem site totally folk problem',
#  'virginamerica like customer service min delay connecting passenger seems long va',
#  'virginamerica thanks outstanding nyc jfk crew moved mountain get home san francisco tonight',
#  'virginamerica absolute best team customer service ever every time fly delighted thank',
#  'virginamerica provide complimentary upgrade first class available seat',
#  'virginamerica need change flight thats scheduled hour min wait time phone im calling intern help',
#  'virginamerica completely awesome experience last month bos la nonstop thanks awesome flight depart time vabeatsjblue',
#  'virginamerica watch oscar jfk gt sfo flight',
#  'virginamerica flight cancelled flightled',
#  'virginamerica failing customer check process link tsa pre check',
#  'virginamerica fidifamilies u terrible airline gave u hotel hotline number said sorry',
#  'virginamerica flight number sfo cabo san lucas arrived yet',
#  'virginamerica chrysichrysic assistance yesterday u cancelled flightled flight give u hotel hotline shame',
#  'virginamerica another delayed flight likingyoulessandless',
#  'virginamerica need register service dog first class ticket sfo gt dulles phone queue hour longer pls advise',
#  'virginamerica rock making watch oscar flight redcarpet oscar oscar',
#  'virginamerica reallytallchris dropped track http co zv pt trk',
#  'virginamerica always xoxo',
#  'virginamerica book seat flight buy even check creates much anxiety frustrated',
#  'virginamerica think paying extra buck rt luggage might afford hiring extra hand sfo lame',
#  'virginamerica best customer service rep world irmafromdallas take cake',
#  'virginamerica please provide status flight cant imagine time web indicates dude weather dallas',
#  'virginamerica amazing staff amp super helpful ran waltdisneyworld princesshalf spoiled comfort',
#  'virginamerica paid premium fly across country cancelled flight flight offer check fee upgrade love sad face',
#  'virginamerica question possible book seat infant giving option want seat',
#  'always together welcome rt virginamerica jessicajaymes welcome',
#  'virginamerica flight home dc sunset globe backtowinter back work refreshed http co vx vbctdlf',
#  'virginamerica understand need dm give answer damaged luggage policy',
#  'virginamerica mean policy destroyed luggage',
#  'virginamerica special assistance travel alone w kid infant priority boarding',
#  'virginamerica thank checking ticket purchased customer happy',
#  'virginamerica website ever coming back online',
#  'virginamerica flight love field sfo definitely cancelled flightled monday february',
#  'virginamerica flight lga dfw time',
#  'virginamerica driver license expired little month fly friday morning using expired license',
#  'virginamerica problem flight booking problem web site keep giving error contact phone phone minute wait',
#  'virginamerica reschedule cancelled flightled flight online change button greyed',
#  'virginamerica rang wait minute book ticket vendor fix site',
#  'virginamerica got flight told today checked email tomorrow unacceptable',
#  'virginamerica flight lga cancelled flighted stuck dallas called reschedule told could get flight today',
#  'virginamerica pairing include red wine white offered redwineisbetter',
#  'virginamerica website',
#  'virginamerica site seems little wonked right may want look tried two browser cs http co qsqmm kf',
#  'virginamerica disappointed agent designated silver status check line dulles airport closed assist pasengers',
#  'virginamerica plan include austin dallas route topnews arab emirate http co aqzwecokk',
#  'virginamerica normal receive reply central baggage baggageissues smh',
#  'virginamerica logan airport waiting checkin flight checkin desk open',
#  'virginamerica jump dallas austin market dallas news http co ewwgi gdx',
#  'virginamerica beat eps view take southwestair va luv investor business daily http co flwmgdahxu',
#  'virginamerica lister show monday',
#  'virginamerica begin dallas austin flight april ketr http co ssuvwwkyhh',
#  'virginamerica congrats got business ewr sfo lax fuck united fl sfo ewr clincher',
#  'virginamerica applied week ago heard back flying week disappointed',
#  'virginamerica love know policy damaged luggage',
#  'virginamerica thank follow',
#  'virginamerica many apology r worse airline even respond cudtomers',
#  'virginamerica shame va making people spend money stranded city airline landing jfk reimburse',
#  'virginamerica ttinac dm',
#  'virginamerica please flight sjc choice fly southwest vega',
#  'virginamerica bad say take day via confirmation email inquired week claim week',
#  'virginamerica flight bos gt la tomorrow cancelled flightled notification wait time hour rebook another airline',
#  'virginamerica way fly elevate gold',
#  'virginamerica guy flight cmh',
#  'virginamerica lot apology thrown customer see sad thanks nothing worst airline ever',
#  'virginamerica flight stuff wrong nothing worst flight ever',
#  'virginamerica issue finding missing item plane help find airport plane headed next',
#  'virginamerica match americanairlines status cool',
#  'virginamerica met match got status another airline upgrade http co h rdktqy asarco e ar',
#  'virginamerica trying book flight guy website let lose business',
#  'virginamerica suck',
#  'virginamerica thanks',
#  'virginamerica dm issue persisting',
#  'virginamerica never rec cancelled flightlation notice left w option fly p driving la red eye mon w kid',
#  'virginamerica trying book flight amp site',
#  'virginamerica flight flying boston tomorrow need home cancelled flightled flight anything',
#  'virginamerica stink flight cancelled flighted psp jfk notification ability rebook disappointed expected better',
#  'virginamerica love guy song dancing high school dance revue',
#  'virginamerica website trying check',
#  'virginamerica done thank quick response apparently faster sitting hold',
#  'virginamerica nervous flight dc lax getting cancelled flightled tomorrow sent dm help',
#  'virginamerica cool picture another virginamerica plane wing site http co b agfd c',
#  'virginamerica keep great work',
#  'virginamerica goodness people love field amazing pressure texas beatstheothers crisis please fly ny',
#  'virginamerica thanks great flight la boston pilot great job landing snow go back la seriously',
#  'virginamerica please get new york area monday afternoon',
#  'virginamerica thanks much awesome support guy rock',
#  'virginamerica seat row recline mention website soreback',
#  'virginamerica flight delayed hour la due mechanical problem handle like pro could tossed u free drink',
#  'virginamerica cancelled flight flight today precipitation scared',
#  'virginamerica twitter team guy killed rescheduling asap thank',
#  'virginamerica guy charged reschedule flight cancelled flighted refusing refund deal',
#  'virginamerica access website safari iphone seems work mac ipad need iphone add passbook',
#  'virginamerica ipad iphone clicking checkin link email received hr flight',
#  'virginamerica mobile site broken show header elevateuser numofpointsavailable number point let checkin',
#  'virginamerica really looking forward flight let know rescheduled diehardvirgin',
#  'virginamerica cancelled flight flight vx one sec delayed airport next cancelled flightled gonna email call reschedule',
#  'virginamerica problem link email check thanks',
#  'virginamerica change another airline get dc today united able land dc cost ugh',
#  'virginamerica looking forward first flight today cancelled flightled along subsequent one',
#  'virginamerica putting great deal pdx la la pdx show love http co eniqg buzj',
#  'virginamerica wish afford fly next friday going back home love everything airline',
#  'virginamerica gonna deal dallas dc deal dc dallas sad',
#  'virginamerica bug report guy',
#  'virginamerica hold time call center bit much',
#  'virginamerica like http co vpqem xuq',
#  'virginamerica site help',
#  'virginamerica best flight attendant ever http co pxdel nq l',
#  'awesome rt virginamerica watch nominated film foot meetthefleet oscar http co dnstitrzwy',
#  'virginamerica thanks much',
#  'virginamerica trying reset password email never arrives help',
#  'virginamerica airline based silicon valley disruption fcmostinnovative incubator fastcompany http co wu lbcncr',
#  'virginamerica nicely done',
#  'virginamerica looking forward watching oscar flight home tomorrow might even get something bubbly drink',
#  'virginamerica reason delay departure vx jfk afternoon',
#  'virginamerica today flight palm spring ca jfk ny cancelled flightled',
#  'virginamerica hahaha virginamerica guy amazing love guy',
#  'virginamerica sound like fun',
#  'virginamerica update flight jfk gt lax',
#  'virginamerica spruce moose',
#  'virginamerica cs site right please fix site unusable',
#  'virginamerica flight vega boston today checked online bag count register fix somehow',
#  'virginamerica classiq luv virgin america greetingz',
#  'virginamerica hi trying check website working tried different browser problem continues',
#  'virginamerica thanks great customer service today amp helping get travel sorted',
#  'virginamerica thanks guy sweet route rockies airplanemodewason',
#  'virginamerica love music blasting gate boston waiting flight sanfrancisco could get iced coffee',
#  'virginamerica passenger flt assaulted flown trust banned crew filed report faanews',
#  'virginamerica current bug website show select departure city selecting destination city http co sllyibe vq',
#  'virginamerica luggage severely dented missing wheel coming baggage claim san luggage agent miranda think help',
#  'virginamerica thank easy itinerary shift impending weather quick painless amp free',
#  'virginamerica love see girl inspired become pilot rt free woaw event march abq http co rfxlv kgdh',
#  'virginamerica thanks good time back vodkatonics entire flight sfo',
#  'virginamerica beat expectation share take santa cruz sentinel http co qm dqbai g',
#  'virginamerica plan start flying direct dal la',
#  'virginamerica big love gratitude mpower w http co agr kncpf werin oscar vipswagbags avalonhollywood http co ybmbgs dhn',
#  'virginamerica great job adding little luxury aesthetic improve air travel experience thank keep',
#  'virginamerica requested window seat confirmed window got stuck middle seat good way treat silver member',
#  'virginamerica grand budapest hotel oscarscountdown',
#  'virginamerica missed newsvp next trip',
#  'virginamerica wtf paid direct flight purpose stop fuel exhausted frequent flier nothing inconvenience',
#  'virginamerica something wrong website safari iphone',
#  'virginamerica thanks gate checking baggage full flight dfw lax giving early boarding sweet',
#  'virginamerica already checked page expired x',
#  'virginamerica boo refunding seat upgrade fee want buy first place',
#  'virginamerica share rise q financial result usa today http co lf pefe',
#  'virginamerica add pillow instead lie flat seat first class arm race http co rgywjbbhm',
#  'virginamerica see',
#  'virginamerica way take advantage mayweatherpacquiao',
#  'virginamerica know flying virgin fight mayweatherpacquiao',
#  'virginamerica inflight team make experience amazing',
#  'virginamerica cutest salt pepper shaker ever think guy get better http co vc keulg j',
#  'virginamerica moved seat notice better seat cabin select behind row selected disappointed',
#  'virginamerica share q result iol http co xz qeg nef',
#  'virginamerica fav airline',
#  'virginamerica hot female pilot sweet dca sfo',
#  'guy going start flying paris virginamerica lizautter welcome',
#  'virginamerica policy flying surgery still waiting answer tell doctor',
#  'virginamerica already contacted central baggage amp sent dm renttherunway charging dress lost suitcase help',
#  'virginamerica thank',
#  'virginamerica anything going website getting lot error past minute',
#  'virginamerica think left something plane yesterday call ah',
#  'virginamerica need follow back order dm',
#  'virginamerica need start flying kciairport',
#  'virginamerica told check airline regulation first contacted',
#  'virginamerica virginatlantic checked flight sfo lax amp told atlantic flying club gold get benefit',
#  'virginamerica husband ordered three drink via screen never came awesome',
#  'virginamerica soooo guy going leave seatbelt light flight barely call turbulence',
#  'virginamerica policy flying surgery',
#  'virginamerica post second consecutive full year net profit atwonline http co tvb zbzvhg',
#  'virginamerica funny story website broken missing javascript stylesheets checkin process dislike',
#  'virginamerica would love virgin like gopro',
#  'virginamerica result handily exceed forecast nytimes http co gonmrwem',
#  'virginamerica applied position flylaxairport wondering guy received application',
#  'virginamerica achieves second year profitability despite revenue pressure capa aviation http co zsuztnaijq',
#  'virginamerica give positive outlook see increased competition reuters http co jeu od eyj',
#  'virginamerica trying check ct flight tmm desktop website working sort caching bug so',
#  'virginamerica weather delay gt next week jfk bos dca',
#  'virginamerica madbee check website go airport',
#  'virginamerica guy know check link email broken http co npxb obmr',
#  'virginamerica pilot say expect choppy landing nyc due gusty wind w temperature degree amp w windchill',
#  'virginamerica loved wait monday return flight mostly watch inflight safety video sorrynotsorry',
#  'virginamerica lost luggage day ago flight vx lax iad amp calling every day response please give back stuff',
#  'virginamerica flight booking problem section website seems broken chrome might wanna look',
#  'virginamerica hi wanted see new route planned year newark love flying guy hope',
#  'virginamerica mean probably inappropriate board',
#  'virginamerica happy spend day together let',
#  'virginamerica missed flight standby work',
#  'virginamerica understanding helped thx comp',
#  'virginamerica brought way across country today see http co tkauygcpms',
#  'virginamerica thank absolutely',
#  'virginamerica look like broken link asset http co oardjjgrrd',
#  'virginamerica ready let say together noooo turbulence today',
#  'virginamerica manage itinerary section website seems broken http co pujvcelng',
#  'virginamerica check site look like every time load http co kacy awdbw',
#  'virginamerica u help freyabevan fund need urgent treatment old battling cancer could u help flight freyasfund',
#  'virginamerica may start service hawaii sanfrancisco year http co ypo nyprzl biztravel',
#  'virginamerica carrier le half price round trip fare stunned http co ukdjjijrow',
#  'virginamerica wtf happening pdx late flight march one way sfo',
#  'virginamerica add dtw sold',
#  'virginamerica free drink flight back free promo',
#  'virginamerica ssal thanks',
#  'virginamerica momma made',
#  'virginamerica please contact portfolio left flight vx jfk sfo tonite seat need returned call',
#  'virginamerica help flight jkf tonight seat c left portfolio need back',
#  'virginamerica shrinerack seattle bound wifey got duffle vday keeper holla http co jloiblnair',
#  'virginamerica luggage gone filed paperwork promised call email still resolution response central luggage',
#  'virginamerica debbie baldwin gave rockstar performance safety demo evening vx la sfo bestcrew sherocks',
#  'virginamerica thanks',
#  'virginamerica thanks taking care suuperg flight rockstars travel',
#  'virginamerica thanks lovely soft view travel san sfo http co cnctl g ef',
#  'virginamerica requested mileage challenge status several week ago online heard back get help',
#  'virginamerica trying book ticket nyc facing super fun broken styling worry keep trying',
#  'virginamerica many thanks follow ourprincess freyasfund usa bandie looking help http co ujfs zi kd',
#  'virginamerica nice lofty view flylaxairport silverstatus http co f tp dawbd',
#  'virginamerica applied status match feb got confirmation email day still news though guy dropped ball late flightly',
#  'virginamerica new go airline',
#  'virginamerica virginatlantic gma americanair help ourprincess need help usa http co aztdaer',
#  'virginamerica adore looking forward flight austin two week',
#  'virginamerica glad mentioned took first virgin flight year back transformative experience',
#  'virginamerica flight booking problem flight uphold status match tax ticket count earned status point statusmatch virginamerica',
#  'virginamerica trying check look like site',
#  'virginamerica spending birthday night dal dca get home',
#  'virginamerica sent couple message email provided avail try next year cheer',
#  'virginamerica first time flying virgin went sanfrancisco thanks smooth ride easily new fav airline',
#  'virginamerica seriously though direct flight sfo fll may',
#  'virginamerica really experience hoping w forced check small carry w nothing empty cabin space board',
#  'virginamerica wjere luggage slow lax',
#  'virginamerica jump dallas austin market http co szr pioa',
#  'virginamerica spoke representative offered solution loyal customer fly virginatlantic well',
#  'virginamerica deeply disappointed birthday promo applied trip booked mere day received email',
#  'virginamerica happened direct flight sfo fll looking may see connecting help dontdothistome',
#  'virginamerica help left blazer kooples jacket bag rd row second seat right gate lax flight sfo',
#  'virginamerica partner visa checkout mobile payment method help boost mobile conversion rate etailwest payment visa',
#  'virginamerica promoting product problem southwest recommend noneother best http co tfanxbh cf',
#  'virginamerica love guy pls get direct route la au',
#  'virginamerica would like help flight please',
#  'bruh virginamerica giannilee turn vxsafetydance',
#  'virginamerica course work virginatlantic obsessed entire virgin family',
#  'virginamerica ok first time flying tonight',
#  'virginamerica digging swanky pink mood lighting flight nyc sfo need cabaret singer think',
#  'virginamerica done need receipt asap could please help',
#  'virginamerica embossed badge patch superior one currently using http co fq xelbon',
#  'virginamerica vx jfk la dirty plane standard',
#  'virginamerica flight vx headed la jfk dirtiest va plane ever sad great airline',
#  'virginamerica got squared away someone picked soon tweeted tweeted sooner',
#  'virginamerica avis rental continue button work website book car tried time phone suck',
#  'virginamerica delayed',
#  'virginamerica currently minute hold cust service need anything add lap child reservation',
#  'virginamerica add pillow instead lie flat seat first class arm race http co sfjduahx z skift',
#  'virginamerica karinslee course fun celebrating thanks happy chinese new year',
#  'virginamerica flight booking problem last second flight next week sfo san chance want gift promo code since love guy',
#  'virginamerica comenity bank joke please change nothing constant problem bank',
#  'virginamerica dm u also add',
#  'virginamerica grandma ella th would lt bday greeting flight crew stewardess eastern airline',
#  'virginamerica bought tix atx dallas route thanks adding love yr airline amp yr website best transactional site ever',
#  'virginamerica anytime sugafly',
#  'virginamerica gave credit late flight flight yesterday great service wow moment unexpected gesture',
#  'virginamerica need receipt flight change send one',
#  'virginamerica submitted status match request back still heard flying monday look accelerate',
#  'virginamerica safety video http co cqmm nue loved first cross country flight livewelltraveled sytycd',
#  'virginamerica look fat look yummy',
#  'virginamerica ceo say southwest amp jetblue strayed low cost model http co sctomh',
#  'virginamerica brilliant brisk boston cue vx http co rmznivgmg',
#  'virginamerica atlantic plough lone furrow middleeast http co fvudmh pf thenationaluae',
#  'virginamerica atlantic plough lone furrow middleeast http co dcobokn ee thenationaluae',
#  'virginamerica atlantic plough lone furrow middleeast http co vw p tlh thenationaluae',
#  'virginamerica omg omg nonstop dallas austin virgin',
#  'virginamerica plane really pretty thought u know',
#  'virginamerica flying hawaii',
#  'virginamerica pulling hair trying book flight u site work iphone ipad computer help',
#  'virginamerica thank',
#  'virginamerica get help support ticket day incident thank',
#  'virginamerica good home texas moodlighting http co n bvzty zi',
#  'virginamerica cannot even open laptop seat c paid premium let',
#  'virginamerica seat c cannot even open laptop paid extra seat',
#  'virginamerica guy starting flight end month guess still road tripping feb',
#  'virginamerica thanks needing way make austin trip dca come',
#  'virginamerica announced new route austin w fare way http co ga pbamu c',
#  'virginamerica cool never ur plane',
#  'virginamerica dollar lax la fare',
#  'virginamerica great well deserved',
#  'virginamerica fyi info virginamerica com email address say contact password reset email exist email bounce',
#  'virginamerica status match week gone news flt next week hope flt count towards requirement cust svc help',
#  'virginamerica website suck donkey dick thought know best',
#  'virginamerica still develop app favorite airline',
#  'virginamerica crap channel pay watch uk tv',
#  'virginamerica got set thanks',
#  'virginamerica channel year',
#  'virginamerica thing see passbook virgin mobile mexico integrate',
#  'virginamerica giant virgin america match made heaven',
#  'virginamerica thank goodness also see friday nwk gt sf boom',
#  'virginamerica come iphone app still using making waste paper',
#  'virginamerica back seat entertainment system accept credit card apostrophe surname apostrophefail',
#  'virginamerica vx use lga slot instead today adding au make le likely',
#  'virginamerica helping step tinder game tindertips tinderchamp http co jbmvvha',
#  'virginamerica luv ur people product thing u charge herbal tea black tea caffeine drinker',
#  'virginamerica thank see soon excited see expansion destination spread wing',
#  'virginamerica announces new nonstop connecting austinairport amp dallaslovefield intro http co qxnoaqtyn http co jk qmdfqgf',
#  'virginamerica add austin dallas love field route http co xwjol flh http co aormfkac',
#  'virginamerica sad learn longer fly sfo gt phl hope return',
#  'virginamerica tweet cancelled flight chng fee flight rebook one affiliate afiliates',
#  'virginamerica incredible customer service ever experienced refreshing',
#  'virginamerica see virginamerica come philadelphia phl',
#  'virginamerica dreaming really open route dallas austin mean houston might next',
#  'virginamerica omg finally',
#  'virginamerica start xweekly flight dallas dallaslovefield austin apr avgeek',
#  'virginamerica nice see expanding texas forget u sandiego would love see flight',
#  'virginamerica kinda sucked earphone jack work flight may want look future passenger',
#  'virginamerica poor experience first computer problem seat malfunction stuck missing meeting san diego',
#  'virginamerica battle southwestair dallaslovefield austinairport route http co rlz ebk x via usatoday',
#  'virginamerica thankyou dal au route make day',
#  'virginamerica awesome deal dal au way http co xcvqxykg',
#  'virginamerica miss nerdbird san jose',
#  'virginamerica love taking southwestair backyard consumer win biz competes',
#  'virginamerica flying love austin excellent news',
#  'virginamerica make every vx plane nerdbird austin one getting nerd love',
#  'virginamerica please add frequency pdx portland',
#  'virginamerica congrats vx new route',
#  'virginamerica tried offered charge additional k new ticket stranded thurs st time last time',
#  'virginamerica americanair u help flight get old battling cancer need treatment freyabevan fund',
#  'virginamerica never bad experience one took cake extortion carry item well',
#  'virginamerica spend hour worrying item carryon would broken stolen since carry plane lock bag',
#  'virginamerica group e told room bin got plane room least bag row',
#  'virginamerica thanks making flight lax jfk nightmare forcing check carry bag gate',
#  'virginamerica lot flight book site working phone waiting minute',
#  'virginamerica flight artisanal cheese wine pairing',
#  'virginamerica virgin america fly direct seattle nyc boston',
#  'virginamerica classy',
#  'virginamerica sure lot jfk lhr flight go lot faster mph strong tailwind',
#  'virginamerica minus minute elevate silver upgrade window open freeneversucks',
#  'virginamerica save tomorrow',
#  'virginamerica taking year fly home dallas get shit together',
#  'virginamerica jezziegoldz club virgin bumping new york http co haqc gdg c',
#  'virginamerica jezziegoldz would rough trip luckily virginamerica flight weather',
#  'virginamerica thestarter',
#  'virginamerica please come minneapolis st paul',
#  'virginamerica another perfect flight come plane sun visor stay carrier make raise',
#  'nice rt virginamerica man steel might faster wifi saying sciencebehindtheexperience http co fgrbpazsix',
#  'virginamerica love dancing little richard cool bean',
#  'virginamerica use passbook still love though lt use email future',
#  'virginamerica thanks free birthday point right',
#  'virginamerica application io looking saw virgin mexico lt',
#  'virginamerica man steel fly city though frequency',
#  'virginamerica thanks much sharing added site http co tsvibtvt h',
#  'virginamerica good point',
#  'virginamerica heard virgin mobile hotspot',
#  'virginamerica got cheese plate flight',
#  'virginamerica flight',
#  'virginamerica dad segway best part whole infographic',
#  'virginamerica plan short haul airline europe would defiantly fly guy',
#  'virginamerica wifi better seating',
#  'virginamerica come abc one network channel',
#  'virginamerica started flight scolding using overhead bin offered person seated next',
#  'virginamerica great return call day ask myvxexperience',
#  'virginamerica airline cancelled flighting flight bos helping customer get home virgin saying good luck',
#  'virginamerica dear virgin customer stranded sf day amp cost least accommodate',
#  'virginamerica use next airline commercial lol http co pxexilsjbs',
#  'virginamerica grouping virgin others bos weather exposed actual cu serv model never flight booking problem virgin',
#  'virginamerica one traveler affected boston storm shocked virgin complete apathy toward customer',
#  'virginamerica umm reason someone different contact contact get definitive answer',
#  'virginamerica trying make change advance hour prior tried online earlier wanted change fee',
#  'virginamerica way change main cabin main cabin select flight without paying change fee penalty',
#  'virginamerica guy perfect always lt wervirgin',
#  'virginamerica thanks best customer service left industry',
#  'virginamerica give silver status month',
#  'virginamerica really wish fly fargo fargoairport fare amazings',
#  'virginamerica mood lighting point reclining seat kickin foot',
#  'virginamerica group got cancelled flightlation fee waived ticket booked rep help either',
#  'virginamerica sign bonus enroll elevate',
#  'virginamerica got pm newark home la folk ewr incredible letsgohome',
#  'virginamerica morning question regarding elevate point amp flight dm',
#  'virginamerica still waiting see starryeyes dev',
#  'virginamerica wondering guy recieved dm able potentially respond asap',
#  'virginamerica flying lax sfo looking awesome movie lineup actually wish long haul',
#  'virginamerica book town fare way restr http co xrdtov nl http co byackc jenniferdawnpro',
#  'united thanks',
#  'united thanks taking care mr happy customer',
#  'united still refund word via dm please resolve issue cancelled flightled flight useless assistant trip',
#  'united delayed due lack crew delayed long line deicing still need improve service united',
#  'united even international flight glasgow u orlando newark min',
#  'united think boarded flight au early think',
#  'united understand tough way get airport w serious risk accident steep price',
#  'united gate agent hooked alternate flight way prevent constant issue would rock',
#  'united flying gla mco week long airport departure international domestic ta',
#  'united thanks',
#  'united thanks ticket',
#  'united law policy',
#  'united worst nonrefundable first class ticket oh select global fc system auto selects economy w upgrade',
#  'united cheertymedad buy tix day flight transfer tix flawed security logic flawed customer service',
#  'united start claim week unrealistic really supposed go long car seat child ridiculous',
#  'united follow please airline beautifull',
#  'united sure united info system',
#  'united car seat lost united reimburse new one pair shoe necessity child',
#  'united submitted response link sent',
#  'united yes david allan send email number kmm v l km case',
#  'united highbuddyyy totally suck cousin worked phl said united',
#  'united wanted let know wonderful rosetta gate agent working flight dan ase let know wasappreciated',
#  'united yes paper voucher got january th',
#  'united beginning feb called united said would send another voucher mail never got anything tiredofwaiting',
#  'united internet great thing emailing executive company maybe respond timely manner',
#  'united need use chase united club pas yr old son come pas',
#  'united suppose number',
#  'united thats weak see ya hey virginamerica',
#  'united flew back w company since united didnt earlier flight',
#  'united lost voucher given miami aeroport jan use',
#  'united trying book award september need flight aegeanairlines show even w many award seat availab',
#  'united sure drive total hour get bag like explain debacle one want talk',
#  'united cheertymedad gee like almost caring ppl think int trusted adult w daughter',
#  'united see told repeatedly pilot late flight kept getting late flightr boarded defibrillator issue',
#  'united preferred security line anymore tsa pre check pull silverairways partner flight platinum spoiled',
#  'united newarkliberty airport need indicate different gate terminal amp c flyingainteasy',
#  'united yes please newly married trying update last name preexisting international flight seems easy',
#  'united united refuse reissue lost voucher plane take due mechanic badcustomerservice',
#  'united also run instructed shattered computer http co oaflfr wxb',
#  'united yes agent last minute one agent rude thankfully ladan nice',
#  'united right overnight miami',
#  'united client hr layover iah day claim amp recheck luggage taken care',
#  'united trying find loaner seat new used used car seat illegal according safety regulation',
#  'united dmed detail',
#  'united iah charlotte baggage claim rep latrice h customerservice non existent ignored customer inappropriately touched customer',
#  'united kewl also let know overhead bin row inop love good abbreve',
#  'united thanks help got need issue austrian guess sit awhile longer',
#  'united uctraveladvisor would loved respond website saw really long form business new seat bad',
#  'united refund flight voucher another flight different airline expense today hour drive inconvenient',
#  'united received call back day infant car seat supposed go anywhere child',
#  'united thanks concern contact customer care upon return australia',
#  'united well sitting ground time waiting gate tiredofthis',
#  'united airport snow removal method keep good work folk cessna become http co v tmusjvu',
#  'united need guy book plane concern travel someone else moving forward',
#  'united measly e certificate appreciate loyal customer wait hr tarmac ua unacceptable',
#  'united email address username sign available',
#  'united thank able claim interim expense cost stuff',
#  'united rude rude',
#  'united get boarding pas austrian airline codeshare flight rebook incls hour layover amp stuck outside sec',
#  'united received flight united truly break guitar unitedbreaksguitars wantmymoneyback',
#  'united flew telaviv paid third suitcase even make plane besides impolite service',
#  'united bag still colo spring disabled search unfamiliar airport look bag good outcome',
#  'united shame flex ticket transfer rule even calling neurosurgery icu enough',
#  'united denver said handle baggage made colo spring gave number call help either',
#  'united guy need serious training customer service many better option put way guy handle ur mistake',
#  'united ord dca',
#  'united found problem avoided like plague told find supervisor',
#  'united zcc u cancelled flight flight h advance need connect flight reschedule link helping help gf waited month see',
#  'united flying',
#  'united addition first flight delayed hour arriving destination hr late flight',
#  'united cancelled flighted flight rebook u added flight drive denver kc thanks',
#  'united announcement pre boarding address mobility disability requires travel lot stuff preboard',
#  'united flew united last month experience awesome',
#  'united travel booked thru united group dept okc ticket agent le willing help connection lax',
#  'united v upset disability service told one employee carrying medical equipment rude',
#  'united thnx quick reply think assist intl grp put considerable inconvenience today',
#  'united wont transfer flight ticket accompany yr old active military mom emergency brain surgery wow',
#  'united getmeontop week late flightr still received mile mileageplus gift card starbucks card handed',
#  'united k always hoping improvement',
#  'united yet complained guy checked luggage throwing bag around unfortunate coincidence hope',
#  'united okc ticket agent roger mclarren sp le helpful intl group travel problem find supervisor help',
#  'united mobile apps need construction ground o category expensive get right',
#  'united another fail united ticket agent okc le helpful could care le problem american come',
#  'united also working wc coach good thing bird landed ahead schedule use wc stat',
#  'united o controlled rather verizonwireless app new',
#  'united sent email customer care telling may break sincerely hope help',
#  'united silly flying delta today united club staff attendant surly unhelpful always seem bothered pesky folk',
#  'united phone number find call flight reservation',
#  'united well fix missing buddy th bday negligence attempt make',
#  'united believe help customer service like said want number someone fix',
#  'united helped baggage service desk said bc tsa screening fll bag made bag ewr',
#  'united mobile boarding pas disappeared phone standing line board second time week hmm',
#  'united record rozana newark lovely helpful choosekind',
#  'united last night ord lga',
#  'united thx update',
#  'united thank',
#  'united dm nut',
#  'united explain eager flight attendant trying ask vision ccicanine guide dog',
#  'united point asking detail servicedog book flight crew read continued',
#  'united tried one available bogota everyone rude houston stuck hour guy',
#  'united worst unitedflightsever ua la iad mechanical problem took land fix delayed wtfodds',
#  'united despite bag making newark good informative email tracking update help',
#  'united going ua outbound flight last thurs delayed hr long delay worst unitedflightsever',
#  'united worst unitedflightsever ua iad la mechanical problem switched aircraft delayed hour',
#  'united crashed trying check',
#  'united wow deal plus seat available easy change make customer happy',
#  'united thanks info already knew',
#  'united airline trouble winter amp getting good customer service contact http co aqjn hwnac negotiate resolution',
#  'united logan boarding gong show due lax carry enforcement bin full coat room bag u need better system',
#  'united thank',
#  'united blackmailed paying extra return ticket nullified san francisco airport terrible service rep scam',
#  'united email address reach long dm',
#  'united disappointed u didnt honor credit given ur mistake taking business elsewhere',
#  'united ua still waiting supposed depart',
#  'united credit last trip never came mail',
#  'united ok month waiting hear airline gave quite bit day requested terrible service',
#  'united process ever end still waiting reply since month pathetic customerservice',
#  'united going website flight booking problem three ticket today booted system umpteen time',
#  'united get account number website say email unavailable',
#  'united need book two one way order fly unaccompanied minor',
#  'united received bag last night still missing one',
#  'united simonroesner need upgrade seat even economy plus like sitting concrete bench',
#  'united pls help baby hannah get life saving surgery requires need help pls donate rt http co kqnrrp',
#  'united bet wont honour like mine ey',
#  'united nd flight also delayed pilot boarded sit scheduling',
#  'united guess much ask huh',
#  'united hard stay upset someone least try show remorse',
#  'united way simple apology go long way even hollow one obvious care well',
#  'united one time thing either shocking pattern repeated neglect disrespect',
#  'united finger crossed amp intact disappointed experience actually saying enjoyed using',
#  'united incredibly easy fix would rather stay comfort zone get forced mine',
#  'united july zero excuse date system cause problem like',
#  'united everyone around u sitting friend family member booked ticket october december bought',
#  'united sure talking going nonstop flight sna sfo sfo ewr',
#  'united moving americanair united talk service',
#  'united please good weekend',
#  'united asked legitimate question systemwide v localized problem got back unrelate flightd copy paste better',
#  'united time call need ski go airport get faith united',
#  'united see guy amazing one company continually make mistake yet fails held accountable error',
#  'united tourist wonder super tide tide century french u k coast http co gxdqortss',
#  'united yeah sorry always problem united international reputation problem',
#  'united yall probably work',
#  'united maybe bbbne sd k ia would care hear went whoever listens issue caused',
#  'united wonder sharing fb insta would produce number character really limit story telling',
#  'united telling number call left airport negligent pilot staff',
#  'united could email resent doesnt appear arrived',
#  'united yes please trying get pop newark',
#  'united follow order dm come',
#  'united united coupon make broken entertainment system hour flight seriously ridiculousness learncustomerservice',
#  'united drop bag overnight amp leaving week supposed hold bag',
#  'united dm detail still response book today',
#  'united know probably way get cheaper airfare ticket flight leaving hour',
#  'united someone please explain process happens property found plane passenger leave heathrow',
#  'united able dm confirmation number',
#  'united sent message let know got twitter literate also really going stuck hr',
#  'united unhappy response complaint emailed nd feb ref awful customer service',
#  'united dm work',
#  'united private jet would cool work try',
#  'united given option using united travelbank recent flight booking problem help using recouping fund thanks',
#  'united common keep paper work ready delay flight meeting choosechicago',
#  'united yul ord',
#  'united yep correct got email flight cancelled flightled matter flight atl delayed thx',
#  'united k problem getting fll iah sent dm making connection please let know',
# ...
#  'united way making phone call need handle via twitter email web thank',
#  'united please help ethiopia adopting two year old child existing confirmation need add child reservation',
#  'united question onboad volt outlet plane',
#  'united website deserves new design html ftw',
#  'united thanks effing holiday missing full day skiing due baggage team incompetence flyyow',
#  'united twitter letting dm',
#  'united hope',
#  'united agent help person front finish walk away guy behind shocked',
#  'united connection ord exact plane checked carry apparently taken amp left chicago pretty ridiculous',
#  'united encouraged cpap tonight',
#  'united yes file claim soon carousel stopped without bag got email found sched delivery',
#  'united idea monitor mileage member travel pattern enough know change job lose status make transition easier',
#  'united delay den cle manually enter baggage tag really worst cust service day ker friendlyskies',
#  'united tell u flight delayed tell u time min spare say delayed unless sure',
#  'united yes lusaka zambia guess bag never made plane iad',
#  'united flight voucher',
#  'united late flight denver late flight newark let even get disaster checking bag unacceptable',
#  'united let think ever flown problem worst airline period',
#  'united yes filed claim amp hope receive luggage ridiculous purchase item go sleep amp reimbursement',
#  'united ua ord lhr bag loaded min late flight frigid air cabin plane feel like falling apart upgrade long haul fleet',
#  'united flight attendant never served beverage tea checked give ua notcool',
#  'united load balancing system apparently systemwide major impact united airline flight cyberattack',
#  'united unscheduled refueling stop missing connecting flight r home n looking ward bed big pb amp j sandwich',
#  'united americanair spent hundred rectify situation guy go quiet',
#  'united ua sitting ewr nearly hour sked pilot say computer clue leave help',
#  'united americanair end come traveled literally extra day half',
#  'united made upgrade list fly st tomorrow min first time ever statusmatchpaidoff http co atfrkp goy',
#  'united thanks reminder fun ride http co ppva rch f',
#  'united received luggage also looked left snow arrived asking people refunded',
#  'united updated aircraft wifi device entertainment outlet get charge device',
#  'united one scan inside plane asked people line around plane going',
#  'united gate change two delay even crew think airline suck',
#  'united frustrated wasted day due equipment failure',
#  'united computer stopped giving update took flight info app ridiculous keep people updated',
#  'united soooo day offered response assume poor treatment gate agent norm',
#  'united terrific many thanks looking forward back ua tomorrow great flight vancouver',
#  'united call resulted hr hold time amp day wait check suspect code share fare nothing investigated time wasted',
#  'united taken week cust care respond case requesting refund wi fi working get update',
#  'united appreciate effort getting home',
#  'united correct spent hour trying book online receive error clicking final purchase button',
#  'united today finest could prevented one gate agent advising passenger',
#  'united real deal delay flight ua denver vega',
#  'united ua madrid arrived agent mass confusion sent fro ua employee maryjo rude unhelpful',
#  'united system failure bad trend software project like flying airplane thing emergency takeoff',
#  'united lot report system failure delaying flight last week currently sitting tarmac ogg hour',
#  'united rebooting chicago dispatch system need pivotalcf tired sitting plane',
#  'united despite shaky connection look like get home tonight great job united touch go',
#  'united http co hj kq chn however completely control price still displayed http co hj kq chn',
#  'united aircraft closest gate flight one closest gate going chicago',
#  'united tell file claim clothing purchased',
#  'united comically return flight ase two united flight boarding adjacent gate clear plane board',
#  'united grk file reference',
#  'united would contact discus poor experience customer service would give shot',
#  'united ua pacific rim date night cut constantly randomly one spot repeatably',
#  'united trying since file report',
#  'united send email bad experience send back generic response yet another reason never fly',
#  'united mom left kindle flight today burgundy case light seat anyone find',
#  'united ticket please refund unnecessary upgrade fee',
#  'united horrible lost carseat expect u use loner carseat safety regulation say illegal use used car seat',
#  'united thank',
#  'decision decision mandarinjourney united love try service offer status match http co xbqqqbrgvf kp',
#  'need info united momsgoodeats great amenity kit pj included status match aa kp',
#  'united care thehipmunk link showed wrong price site site amp responsibility ensure correctness',
#  'united flight lie flat seating stl pdx around date march',
#  'united mllovelace baggage fee waived premier member please see http co u duw mde jp point membership',
#  'united wonderful bag claim people finally bag catch earlier flight original flight landed wastedtime',
#  'united thanks touch',
#  'united thanks karen salisbury iah amazing customer service found daughter bag lost ua made day',
#  'united day late flightr bag left iad united helping everyone tell different story',
#  'united renoairport hi direct flight houston reno begin see day march',
#  'united like continental chicken feat fair',
#  'united assist current flight status flt dfw tomorrow',
#  'united lose gate checked bag den ord direct flight ugh',
#  'united caught earlier flight ord gate checked bag lost hare original flight land minute frustrating',
#  'yes thanks much united whitterbug see spoke reservation team reinstated flight thanks ey',
#  'united captain behalf front office welcome board never heard laughed hard funnycaptain',
#  'united please follow dm missing bag',
#  'united clear luggage comment referencing photo attached flight jac http co pnbajfkmhg',
#  'united great fare',
#  'united left item plane calling non stop one answering please help',
#  'united awesome book next christmas vacatinn december way want devalue mileage plus',
#  'united good number call speak someone fix people luggage saturday',
#  'united thank u secured room night thx helpful customer service rep n dorns thanked u goodenoughmother',
#  'united damn bag',
#  'united well someone tell employee denver baggage claim still bag',
#  'united greeting ua club member idea use air canada lounge yvr flying ua tomorrow',
#  'united mexico international u',
#  'united diverted missed connecting flight told bag way msy people cared',
#  'united male agnt la threatens canadian cust cust take pic gate agent announce help rebook friendlyskies',
#  'united apollochplayers want go home tonight cancelled flight last leg reserv w permission ph rps',
#  'united stressed rude agent overwhelmed delyd flight la den yelling several people pretty friendlyskies',
#  'united landed boston last night hour traveling rough tho',
#  'united fail cancelled flightled flight frm gjt used reserv home iah sea reflight booking problem w permission ph rps',
#  'united made fly list airline wait connector late flight stuck iah',
#  'united deal u provide voucher overnight cozy floor ohare gross helpmeplease anyonethere',
#  'united also mere fact go online issue statement vice calling talking directly one good example',
#  'united thank flew newark vail eagle',
#  'united weekend dealing company would say otherwise',
#  'united http co hpsqvrjk flight gone got plane businesstravel goodenoughmother',
#  'united proper response sorry wait flight look issue delta would handle',
#  'united customer service terrible stood inline hour flight hour late flightr still bag disgutedindenver',
#  'united please upload march demand entertainment listing website',
#  'united inadequate accident',
#  'united reebok rockinwellness denver international airport http co tkvmhbkec',
#  'united thank responding quickly helpful tool dustyob',
#  'united boarding time show min gate agent started showed check bag http co zcbjyo lsn',
#  'united agent la letting customer know help rebook delayed flight den unfriendlyskies http co quzvmk rtr',
#  'united empathizes w disappointment stclass flight w nonworking entertainmnt worth unfriendlyskies http co loeco gmvd',
#  'united work',
#  'united seen message today mcdonnell douglas dc model hear read goodnight',
#  'united searched mileage ticket bom find single one saver award see play earn mile use',
#  'united flight arrives minute early wait hour bag',
#  'united issue fact one even called despite promise confirm bag location',
#  'united girl gotta get flight name change bought one mean ex boyfriend need girl trip stat',
#  'united thank signed notification shall watch wait',
#  'united still waiting hear back wallet stolen one plane would appreciate resolution',
#  'united would love someone could get back austin tonight wish wait til tomorrow morning',
#  'united flysaa lost baggage heard different thing different employee united flysaa said nothing',
#  'united c think mile repair damage done interesting travel united exp worst flight ever',
#  'united flight dfw tuesday far advance give notice cancelled flightled',
#  'united signed notification first trip updated sure happened',
#  'united thank took care everything made right experience used opened app find flight changed',
#  'united line response waiting tomorrow morning flight overbooked',
#  'united took exact aircraft lax day ago fit problem agent today told nonsense policy change',
#  'united helpful agent club helped baggage fee night life stop business silverairways',
#  'united never heard http co qdebyahqfm',
#  'southwestair charge ticket change fee incur mysterious cost incur united',
#  'united exhausted amp frustrated link fb post abt travel issue http co larkc vc',
#  'united denied getting plane w getting chance prove fit rookie read bio',
#  'united exactly point fit premier access boarding group return ticket yr',
#  'united never experienced worst customer service placing blame codeshare partner assuming responsibility unacceptable',
#  'united currently board check terrible staff rude expensive luggage thrown around etc',
#  'united fucked voided ticket kept money even apology never fly airline unitedairlines',
#  'united worst customer svcs kevin rep call center must investigated baggage lost help argument',
#  'united sell ticket silverairways http co onhxhco bk terrible service ua staff cannot reach silver',
#  'united got demoted gold cuz hubby got pqd tho enuf spent gold spousal discrimination angry',
#  'united thank',
#  'united direct flight belfast intl newark resume winter break thanks',
#  'united favorite way travel thank http co vgn x ckg',
#  'united yes awful weather appears get home',
#  'united yes lot terrible customer service newark despite raising complaint ignored hence tweet',
#  'united lovely new plane lga ord power outlet',
#  'united tweet id number reveal home address anyone web',
#  'united filed delayed bag report saturday flight cancelled flightled never went anywhere',
#  'united person currently bettween gate lax',
#  'united need land ewr baggage claim file sent employee droppeditoffyet',
#  'united rarely cease amaze worse hope last time fly',
#  'united thank quick response cannot dm follow well',
#  'united icloud yet please help',
#  'united need phone number baggage claim lax mom left phone someone called saying would put',
#  'united response back',
#  'united atrocious customer service',
#  'united honor absurdly low mistake fare http co z jv ilw v usatoday',
#  'united albanyairport delayed departure check bag gate claiming space filled walk open space delay poorcustomerservice',
#  'united cancelled flighted flight reason amp phone hour vacation',
#  'united dfpietra response shaking head back forth tsk better customer service apology',
#  'united thanks k mile rtb europe multiple destination could stop u way way back mileage diff',
#  'united course bag frustrated',
#  'united worst avoid like plague',
#  'united worst airline world',
#  'united someone need dm resolve correctly extremely disappointed service received terrible management',
#  'united premier gold desk change flight waif fee give wrong flight jana acosta salt lake refuse service angry',
#  'united give one thing consistent unfortunately consistent job well alwaysdelayedonunited',
#  'united right angry',
#  'united first time flying united also last time terrible back virginatlantic branson virginatlantic unitedairlines',
#  'united used committed continentalairlines flyer merger remember switched southwestair communicationfail',
#  'united least could offer ticket coach instead cancelled flighting reservation glitch notfair',
#  'united saying made flight poor non communication unaccounted lost time amp lot frustrated flyer standing around',
#  'united think dm would better',
#  'united gate announcement state delay due maintenance yet app say late flight arriving aircraft tell truth unfriendly',
#  'united easily worst company ever experienced lost someone personal possession amp care le',
#  'united app show arriving aircraft early departing flight delayed due late flight arriving aircraft unfriendly',
#  'united already airport hr late flightr still guy really killing today trying stay positive',
#  'united united service level reach etihad let realistically lufthansa ill consider',
#  'united really someone called sick someone forgot call replacement hour late flight take theworst',
#  'united asked flight attendant typical compensation would amp say might get free tv unacceptable',
#  'united done',
#  'united disappointment today simply put rather unpleased thing currently flight delayed cant wait get home',
#  'united round trip non english speaking friend stranded twice hour time staff member rude',
#  'united found group people actually hate people isi thats right united airline',
#  'united nope walked amp orf terminal amp united agent found showed last minute board u many panicked people',
#  'united thank',
#  'united time finally get dallas could driven le frustration cheaper',
#  'united trying get final destination need compensation hr personal time wasted',
#  'united guy really customer service clue could spent effort clearing bin rollerboards instead art project mine',
#  'united priority iove',
#  'united pleased premier platinum',
#  'united put bag plane seattle flight waiting line talk someone bag status matter',
#  'united campilley hahaha american company would say great sarcasm',
#  'united think actually like screen campilley',
#  'united apparently asking people board plane big miscalculation made',
#  'united shame choosing united may difference reuniting aging friend never seeing poorservice',
#  'united hi guy general enquires email address please thanks david',
#  'united checking status claim going month attention upset',
#  'united flight delayed due maintenance lit caused miss connection iah msy help',
#  'united unitedairlines pls fix aspenbaggagefail issue pay way aspen flight cancelled flight left u cold den',
#  'united read bio see work never encountered airline disappointed understatement',
#  'united customer care email phone rep speak many issue placed character',
#  'thank united truu tall certainly take look please follow dm confirmation number assistance jh',
#  'united process recovering car rental condo rental florida called united alternate flight noanswer',
#  'united buying yo seat leg intl trip car seat required allowed child still sit w mom takeoff',
#  'united thanks listening definitely person line thought absurd',
#  'united waiting tarmac gt hr apparently ua overweight amp returned gate wtf fb',
#  'united thank mention boarded asked person measure bag another woman men asked',
#  'united leave tarmac united gate agent cannot agree head count min counting people max epicfailunited',
#  'united real dedication amp concern apology fix issue miserable issue past mo',
#  'united blocked dm ing would rather complain public forum',
#  'united ok submitted thanks opportunity give feedback',
#  ...]

# %%
Y
# Out:
# 0         neutral
# 2         neutral
# 3        negative
# 4        negative
# 5        negative
#            ...
# 14634    negative
# 14636    negative
# 14637     neutral
# 14638    negative
# 14639     neutral
# Name: airline_sentiment, Length: 14404, dtype: object

# %%
# Sentiment labels are converted into numerical representations

sentiments = ['negative' , 'neutral', 'positive']
Y = Y.apply(lambda x: sentiments.index(x))

# %%
Y.head()
# Out:
# 0    1
# 2    1
# 3    0
# 4    0
# 5    0
# Name: airline_sentiment, dtype: int64

# %%
#Vectorizing the text data
from sklearn.feature_extraction.text import CountVectorizer

count_vectorizer = CountVectorizer(max_features = 5000, stop_words = ['virginamerica','united'])
XFit = count_vectorizer.fit_transform(cleaned_text_data).toarray()

# %%
XFit.shape
# Out:
# (14404, 5000)

# %%
#Creating the model
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
sent_model = MultinomialNB()

# %%
#Splitting of training and testing data
X_train, X_test, Y_train, Y_test = train_test_split(XFit,Y, test_size = 0.3)

# %%
#Fit the model
sent_model.fit(X_train,Y_train)
# Out:
# MultinomialNB()

# %%
#Evaluating the model
y_pred = sent_model.predict(X_test)

# %%
#Plotting the confusion matrix
from sklearn.metrics import classification_report

classification = classification_report(Y_test,y_pred)
print(classification)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.85      2709
#            1       0.61      0.48      0.54       904
#            2       0.73      0.65      0.69       709
#
#     accuracy                           0.77      4322
#    macro avg       0.72      0.68      0.69      4322
# weighted avg       0.76      0.77      0.76      4322

# %%
#Saving the model for deployment
import pickle

with open("sent_model.pkl", "wb") as f:
    pickle.dump(sent_model, f)
